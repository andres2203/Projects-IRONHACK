# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
## Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
max_loops = 3

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
min_points = 2

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
computer = []

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
choice_nr = ['stone','paper','scissors']
text = 'write a value: \n > stone \n > paper \n > scissors \n >> '
result = []
wins_human = 0
wins_computer = 0
tie = 0
status = [wins_human, ":", wins_computer]
rounds_total = 0

while wins_computer < min_points and wins_human < min_points and rounds_total <= max_loops +1 or wins_human == wins_computer:
    rounds_total += 1
    print("Round Nr:", rounds_total)
    input_choice = input(text)
    computer_output = random.choice(choice_nr)
    computer.append(computer_output)
    
    while input_choice not in choice_nr:
        print("Input not valid, please try again!")
        input_choice = input(text)
        
    if input_choice == computer_output:
        result.append(0)
        tie += 1
        win = 'tie'
    else:
        if input_choice == 'stone' and computer_output == 'scissors':
            win = 'you won'
        elif input_choice == 'stone' and computer_output == 'paper':
            win = 'computer wins'
        elif input_choice == 'scissors' and computer_output == 'paper':
            win = 'you won'
        elif input_choice == 'scissors' and computer_output == 'stone':
            win = 'computer wins'
        elif input_choice == 'paper' and computer_output == 'stone':
            win = 'you won'
        elif input_choice == 'paper' and computer_output == 'scissors':
            win = 'computer wins'
            
    if win == str('you won'):
        wins_human += 1
        result.append(2)
    elif win == str('computer wins'):
        wins_computer += 1
        result.append(1)
    print(">> you choose:", input_choice,"- the computer choose:", computer_output,"- Result:", win)


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated


# Create two variables that accumulate the wins of each participant


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.


# Print by console the winner of the game based on who has more accumulated wins
if wins_human > wins_computer:
    print("\033[1;37;33m>>>>>> YOU WIN <<<<<<\033[m")
else:
    print("This time you lose")
# Out:
# Round Nr: 1
# write a value:
#  > stone
#  > paper
#  > scissors
#  >> stone
# >> you choose: stone - the computer choose: stone - Result: tie
# Round Nr: 2
# write a value:
#  > stone
#  > paper
#  > scissors
#  >> stone
# >> you choose: stone - the computer choose: stone - Result: tie
# Round Nr: 3
# write a value:
#  > stone
#  > paper
#  > scissors
#  >> stone
# >> you choose: stone - the computer choose: paper - Result: computer wins
# Round Nr: 4
# write a value:
#  > stone
#  > paper
#  > scissors
#  >> stone
# >> you choose: stone - the computer choose: paper - Result: computer wins
# This time you lose

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
rules = {'rock': 'scissors', 'paper': 'rock', 'scissors':'paper'}

rules['rock']
# Out:
# 'scissors'

# %%
# Import the choice function of the random module
import random
# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
while True:
    try:
        max_loops = int(input("How many rounds you want to play? "))
        break
    except ValueError:
        print("value should be an integer!")
        continue

# Assign a list of 5 possible options.
choice_nr = ['stone', 'paper', 'scissors', 'lizard', 'spock']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used


# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
min_points = 2

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
computer = []

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
    
# Create two variables that accumulate the wins of each participant

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
text = 'write a value (stone, paper, scissors, lizard, spock): \n >> '
result = []
wins_human = 0
wins_computer = 0
tie = 0
status = [wins_human, ":", wins_computer]
rounds_total = 0

while wins_computer < min_points and wins_human < min_points or rounds_total <= max_loops-1 or wins_human == wins_computer:
    rounds_total += 1
    print("Round Nr:", rounds_total)
    input_choice = input(text)
    computer_output = random.choice(choice_nr)
    computer.append(computer_output)
    
    while input_choice not in choice_nr:
        print("Input not valid, please try again!")
        input_choice = input(text)
        
    if input_choice == computer_output:
        result.append(0)
        tie += 1
        win = 'tie'
    else:
        if input_choice == 'stone' and computer_output == 'scissors' or computer_output == 'lizard':
            win = 'you won'
        elif input_choice == 'stone' and computer_output == 'paper' or computer_output == 'spock':
            win = 'computer wins'
        elif input_choice == 'scissors' and computer_output == 'paper' or computer_output == 'lizard':
            win = 'you won'
        elif input_choice == 'scissors' and computer_output == 'stone' or computer_output == 'spock':
            win = 'computer wins'
        elif input_choice == 'paper' and computer_output == 'stone' or computer_output == 'spock':
            win = 'you won'
        elif input_choice == 'paper' and computer_output == 'scissors' or computer_output == 'lizard':
            win = 'computer wins'
        elif input_choice == 'lizard' and computer_output == 'spock' or computer_output == 'paper':
            win = 'you won'
        elif input_choice == 'lizard' and computer_output == 'rock' or computer_output == 'scissors':
            win = 'computer wins'
        elif input_choice == 'spock' and computer_output == 'scissors' or computer_output == 'rock':
            win = 'you won'
        elif input_choice == 'spock' and computer_output == 'paper' or computer_output == 'lizard':
            win = 'computer wins'
              
    if win == str('you won'):
        wins_human += 1
        result.append(2)
    elif win == str('computer wins'):
        wins_computer += 1
        result.append(1)
    print(">>> you choose:", input_choice,"- the computer choose:", computer_output,"- Result:", win)

# Print by console the winner of the game based on who has more accumulated wins
if wins_human > wins_computer:
    print("\033[1;37;33m>>>>>> YOU WIN <<<<<<\033[m")
else:
    print("This time you lose")
# Out:
# How many rounds you want to play? 5
# Round Nr: 1
# write a value (stone, paper, scissors, lizard, spock):
#  >> scissors
# >>> you choose: scissors - the computer choose: spock - Result: computer wins
# Round Nr: 2
# write a value (stone, paper, scissors, lizard, spock):
#  >> stone
# >>> you choose: stone - the computer choose: lizard - Result: you won
# Round Nr: 3
# write a value (stone, paper, scissors, lizard, spock):
#  >> stone
# >>> you choose: stone - the computer choose: scissors - Result: you won
# Round Nr: 4
# write a value (stone, paper, scissors, lizard, spock):
#  >> spock
# >>> you choose: spock - the computer choose: paper - Result: you won
# Round Nr: 5
# write a value (stone, paper, scissors, lizard, spock):
#  >> spock
# >>> you choose: spock - the computer choose: lizard - Result: you won
# >>>>>> YOU WIN <<<<<<
